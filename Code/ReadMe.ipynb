# %% [markdown]
# # Project Name
# > Outline a brief description of your project.
# > Live demo [_here_](https://www.example.com). <!-- If you have the project hosted somewhere, include the link here. -->
#
# ## Table of Contents
#
#
# ## 1. Background Information
#
#
# ## 2. Problem Statement
#
#
# ## 3. Data Collection Process
#
#
# ## 4. Data Dictionary
# > ###     Features:
# >> **
# <br>
# <br> *
# <br>
# <br> **Rented_for**  – – the type of event for which the garment was rented.
# <br>*Values: Vacation, Wedding, Everyday, unknown, Party, Date, Work, Formal Affair*
# <br>
# <br> **Size_usually_worn**  – the size usually worn by the customer.
# <br>
# <br> **Height** – the reported height of the customer in inches.
# <br>
# <br> **Age** – the reported age of the customer in years.
# <br>
# <br> **Bust_size**  – the reported bust size of  the customer.
# <br>
# <br> **Body_type** – what body type the customer thinks they have
# <br> *Values: athletic, hourglass, pear, straightnarrow, petite, unknown, fullbust, apple *
# <br>
# <br> **Weight** – the reported weight of the customer in pounds.
# <br>
# <br> **Brand** – the brand of the dress
# <br>
# <br> **Dress_Description** – the specific garment name
# <br>
# <br> **Retail_price** – the retail price of the dress
# <br>
# <br> **Rent_price** – the rent price of the dress
# <br>
# <br> **Number_of_reviews** – the number of reviews left for the particular dress
# <br>
# <br> **Sleeves** – the type of sleeves on the garment has
# <br> *Variables: *
# <br>
# <br> **Neckline* – the type of neckline on the garment
# <br> *Variables:*
# <br>
# <br> **Dress_style:** the cut of the bodice of the dress
# <br> *Variables: There are 100 different dress types.*
#
# > ### Target Variable
#  >> **Rating** – the number of stars out of five stars that the customer left rated the garment with.
#
#
#
# ## Contact
# Created by [@flynerdpl](https://www.flynerd.pl/) - feel free to contact me!

# %% [markdown]
# ##### Table 1. Data Dictionary
#
# Variable | Description | Values|
# ---------|-------------|-------|
# Size   | The size of the dress rented.|Sizes 0 to 24
# Overall_fit  | The overall fit of the garment as judged by customer. |True to Size, Large, Small, Unknown
# Rented_for |   the type of event for which the garment was rented. |Vacation, Wedding, Everyday, unknown, Party, Date, Work, Formal Affair
# Size_usually_worn  | the size usually worn by the customer. | values
# Height |  the reported height of the customer in inches. | values
# Age  |the reported age of the customer in years. |values
# Bust_size  | the reported bust size of  the customer.|values
# Body_type | what body type the customer thinks they have |athletic, hourglass, pear, straightnarrow, petite, unknown, fullbust, apple
# Weight | the reported weight of the customer in pounds. |values
# Brand  |the brand of the dress|values
# Dress_Description | the specific garment name |values
# Retail_price  |the retail price of the dress|values
# Rent_price | the rent price of the dress|values
# Number_of_reviews | the number of reviews left for the particular dress|values
# Sleeves | the type of sleeves on the garment has |Variables:
# Neckline  |the type of neckline on the garment |Variables:
# Dress_style| the cut of the bodice of the dress|There are 100 different dress types.
# Rating | the number of stars out of five stars that the customer left rated the garment with.|values
